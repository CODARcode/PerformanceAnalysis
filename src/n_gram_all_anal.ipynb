# %%
import pickle
# %matplotlib inline
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import glob

# %%
os.getcwd()
os.chdir("../data")
os.getcwd()

df_lst = []
for file in glob.glob("ee*.json.df"):
    print("Processing :" + file)

    with open(file, 'rb') as handle:
        ldf = pd.read_pickle(handle)
        df_lst.append(ldf)
df = pd.concat(df_lst)
# Out:
# Processing :ee-test-for-ml-lammps-128+32.3755463.110.json.df
# Processing :ee-test-for-ml-lammps-128+32.3755463.112.json.df

# %%
df
# Out:
#                                                        kl  time_by_lasttime  \
# 0                              .TAUapplication:MPI_Init()          0.000014
# 1       intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.021761
# 2       intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.021766
# 3       intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.021770
# 4       intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.021775
# 5       .TAUapplication:intmain(int,char**):voidLAMMPS...          0.021758
# 6       intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.021791
# 7       intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.021791
# 8       .TAUapplication:intmain(int,char**):voidLAMMPS...          0.021790
# 9       .TAUapplication:intmain(int,char**):intLAMMPS_...          0.021794
# 10      .TAUapplication:intmain(int,char**):MPI_Type_s...          0.021798
# 11      .TAUapplication:intmain(int,char**):MPI_Type_s...          0.021798
# 12      .TAUapplication:intmain(int,char**):voidLAMMPS...          0.021804
# 13      intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.021809
# 14      voidLAMMPS_NS::LAMMPS::LAMMPS(int,char**,MPI_C...          0.021812
# 15      intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.021812
# 16      .TAUapplication:intmain(int,char**):voidLAMMPS...          0.021809
# 17      voidLAMMPS_NS::LAMMPS::LAMMPS(int,char**,MPI_C...          0.021828
# 18      voidLAMMPS_NS::LAMMPS::LAMMPS(int,char**,MPI_C...          0.021828
# 19      intmain(int,char**):voidLAMMPS_NS::LAMMPS::LAM...          0.021828
# 20      voidLAMMPS_NS::LAMMPS::create():voidLAMMPS_NS:...          0.021835
# 21      voidLAMMPS_NS::LAMMPS::create():voidLAMMPS_NS:...          0.021836
# 22      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.021841
# 23      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.021841
# 24      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.021841
# 25      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.021841
# 26      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.021841
# 27      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.021842
# 28      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.021842
# 29      voidLAMMPS_NS::CommBrick::CommBrick(LAMMPS_NS:...          0.021842
# ...                                                   ...               ...
# 173991  voidLAMMPS_NS::LAMMPS::destroy():voidLAMMPS_NS...          0.932250
# 173992  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932250
# 173993  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932215
# 173994  .TAUapplication:intmain(int,char**):voidLAMMPS...          0.931954
# 173995  .TAUapplication:intmain(int,char**):voidLAMMPS...          0.932254
# 173996  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932255
# 173997  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932255
# 173998  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932257
# 173999  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932257
# 174000  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932257
# 174001  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932259
# 174002  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932259
# 174003  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932259
# 174004  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932259
# 174005  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932259
# 174006  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932260
# 174007  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932260
# 174008  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932260
# 174009  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932260
# 174010  voidLAMMPS_NS::LAMMPS::~LAMMPS():voidLAMMPS_NS...          0.932260
# 174011  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932259
# 174012  .TAUapplication:intmain(int,char**):voidLAMMPS...          0.932255
# 174013  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932705
# 174014  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932707
# 174015  intmain(int,char**):voidLAMMPS_NS::LAMMPS::~LA...          0.932707
# 174016  .TAUapplication:intmain(int,char**):voidLAMMPS...          0.932264
# 174017   .TAUapplication:voidLAMMPS_NS::LAMMPS::~LAMMPS()          0.931951
# 174018                      .TAUapplication:MPI_Barrier()          0.932707
# 174019                     .TAUapplication:MPI_Finalize()          0.933563
# 174020                                intmain(int,char**)          0.000007
#
#         time_diff node_id thread_id
# 0         67328.0     110         0
# 1             4.0     110         0
# 2             1.0     110         0
# 3             1.0     110         0
# 4             1.0     110         0
# 5           162.0     110         0
# 6             1.0     110         0
# 7             1.0     110         0
# 8             4.0     110         0
# 9             1.0     110         0
# 10            3.0     110         0
# 11            1.0     110         0
# 12            1.0     110         0
# 13            1.0     110         0
# 14            1.0     110         0
# 15            2.0     110         0
# 16           70.0     110         0
# 17            1.0     110         0
# 18            1.0     110         0
# 19            3.0     110         0
# 20            4.0     110         0
# 21            5.0     110         0
# 22            1.0     110         0
# 23            1.0     110         0
# 24            1.0     110         0
# 25            1.0     110         0
# 26            1.0     110         0
# 27            1.0     110         0
# 28            1.0     110         0
# 29            1.0     110         0
# ...           ...     ...       ...
# 173991        0.0     112         0
# 173992        0.0     112         0
# 173993      200.0     112         0
# 173994     1710.0     112         0
# 173995        0.0     112         0
# 173996        0.0     112         0
# 173997        0.0     112         0
# 173998        0.0     112         0
# 173999        0.0     112         0
# 174000        0.0     112         0
# 174001        0.0     112         0
# 174002        0.0     112         0
# 174003        0.0     112         0
# 174004        0.0     112         0
# 174005        0.0     112         0
# 174006        0.0     112         0
# 174007        0.0     112         0
# 174008        0.0     112         0
# 174009        0.0     112         0
# 174010        0.0     112         0
# 174011       10.0     112         0
# 174012       30.0     112         0
# 174013       10.0     112         0
# 174014        0.0     112         0
# 174015        0.0     112         0
# 174016     2560.0     112         0
# 174017     4370.0     112         0
# 174018     4930.0     112         0
# 174019   383930.0     112         0
# 174020  5778861.0     112         0
#
# [346177 rows x 5 columns]

# %%
df = df.sort(['time_by_lasttime'], ascending=[True])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-680d34bee415> in <module>()
# ----> 1 df = df.sort(['time_by_lasttime'], ascending=[True])
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'sort'

# %%
import pandas as pd
sf = df.kl.value_counts()
freq = pd.DataFrame({'n_gram':sf.index, 'numberofcalls':sf.values})

# Define max and min threshold
min = 500
max = float("inf")
subset = freq[(freq['numberofcalls'] > min) & (freq['numberofcalls'] < max)]
subset
# Out:
#                                                n_gram  numberofcalls
# 0   voidLAMMPS_NS::Run::command(int,char**):voidLA...          30646
# 1   voidLAMMPS_NS::Run::command(int,char**):voidLA...          30646
# 2   voidLAMMPS_NS::Run::command(int,char**):voidLA...          30646
# 3   voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...          30574
# 4   voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...          30574
# 5   voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...          30574
# 6   voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...          15840
# 7   voidLAMMPS_NS::Run::command(int,char**):voidLA...          15840
# 8   voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...          15840
# 9   voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...          15840
# 10  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...          15840
# 11  voidLAMMPS_NS::Run::command(int,char**):voidLA...          15576
# 12  voidLAMMPS_NS::Neighbor::build(int):voidLAMMPS...          10737
# 13  LAMMPS_NS::Input::command_creator:voidLAMMPS_N...           5792
# 14  voidLAMMPS_NS::Run::command(int,char**):voidLA...           2160
# 15  voidLAMMPS_NS::Modify::initial_integrate(int):...           1440
# 16  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...           1440
# 17  voidLAMMPS_NS::Modify::initial_integrate(int):...           1440
# 18  voidLAMMPS_NS::Modify::initial_integrate(int):...           1440
# 19  voidLAMMPS_NS::Modify::initial_integrate(int):...           1440
# 20  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            744
# 21  LAMMPS_NS::Input::command_creator:voidLAMMPS_N...            724
# 22  LAMMPS_NS::Input::command_creator:voidLAMMPS_N...            724
# 23  LAMMPS_NS::Input::command_creator:voidLAMMPS_N...            724
# 24  LAMMPS_NS::Input::command_creator:voidLAMMPS_N...            724
# 25  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 26  voidLAMMPS_NS::FixNH::initial_integrate(int):v...            720
# 27  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 28  voidLAMMPS_NS::FixNH::final_integrate():voidLA...            720
# 29  voidLAMMPS_NS::Modify::initial_integrate(int):...            720
# ..                                                ...            ...
# 36  LAMMPS_NS::Input::command_creator:voidLAMMPS_N...            720
# 37  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 38  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 39  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 40  LAMMPS_NS::Input::command_creator:voidLAMMPS_N...            720
# 41  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 42  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 43  voidLAMMPS_NS::Run::command(int,char**):voidLA...            720
# 44  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 45  voidLAMMPS_NS::Run::command(int,char**):voidLA...            720
# 46  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 47  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 48  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 49  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 50  LAMMPS_NS::Input::command_creator:voidLAMMPS_N...            720
# 51  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 52  voidLAMMPS_NS::Run::command(int,char**):voidLA...            720
# 53  voidLAMMPS_NS::Modify::final_integrate():voidL...            720
# 54  voidLAMMPS_NS::Modify::final_integrate():voidL...            720
# 55  voidLAMMPS_NS::Run::command(int,char**):voidLA...            720
# 56  voidLAMMPS_NS::Run::command(int,char**):voidLA...            720
# 57  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 58  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 59  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 60  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 61  voidLAMMPS_NS::Verlet::run(int):voidLAMMPS_NS:...            720
# 62  voidLAMMPS_NS::Modify::initial_integrate(int):...            720
# 63  LAMMPS_NS::Input::command_creator:voidLAMMPS_N...            708
# 64  voidLAMMPS_NS::Run::command(int,char**):voidLA...            576
# 65  voidLAMMPS_NS::Verlet::run(int):intLAMMPS_NS::...            576
#
# [66 rows x 2 columns]

# %%
sns.set_context("notebook", font_scale=1.2, rc={"lines.linewidth": 2.5})
for i in range(len(subset)):
    pick_func = freq.iloc[i]['n_gram']
    count  = freq.iloc[i]['numberofcalls']
    lbl = str(pick_func) +'_count_'+ str(count)
    df[df['kl'] == pick_func].plot(x='time_by_lasttime', y='time_diff', kind = 'scatter', title=lbl )
    plt.show()
